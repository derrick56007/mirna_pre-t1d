# %%
# source("http://bioconductor.org/biocLite.R")
# biocLite("limma")

# %%
library(limma)
library(Glimma)
library(edgeR)
# library(Mus.musculus)

# %%
# change this
setwd("C:\\Users\\Pete\\DSC180B-PROJECT")

# %%
file_url = 'https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE44639&format=file'            
raw_dir = "data/raw/"
temp_dir = "data/temp/"
file_name = 'GSE44639_RAW.tar'

# %%
ingest_data <- function(file_url, file_name, raw_dir, temp_dir) {
    if (!dir.exists(raw_dir)) {
        dir.create(raw_dir, recursive = TRUE)
    }
    out = paste(raw_dir, file_name, sep="")
    utils::download.file(file_url, destfile=out, mode="wb")
    utils::untar(out, exdir=temp_dir)
}

ingest_data(file_url, file_name, raw_dir, temp_dir)

# %%
read_all_files_in_dir_with_columns <- function(file_dir, required_columns) {
    files <- list.files(path=file_dir)
    
    all <- list()
    
    for (i in files) {
        fp <- paste(file_dir, i, sep='')
        seqdata <- read.delim(gzfile(fp), stringsAsFactors = FALSE)
        columns <- colnames(seqdata)
        
        has_unidentified_col <- FALSE
        
        # ignore samples with columns not present in required_columns
        for (c in columns) {
            if (!any(required_columns==c)) {
                has_unidentified_col <- TRUE
                break
            }
        }
        
        if (has_unidentified_col) {
            next
        }
        
        cellType = strsplit(fp, "_")[1]
        cellType = cellType[[1]][3]
        cellType = strsplit(cellType, ".txt")
        cellType = cellType[[1]][1]
        
        healthy <- !grepl("P", fp, fixed=TRUE)
        
        # add healthy column
        seqdata$healthy <- healthy
        seqdata$cellType <- cellType
        
        if (length(all) == 0) {
            all <- seqdata
        } else {
            all <- rbind(all, seqdata)
        }
    }
    
    return(all)
}

required_columns <- list("miRNA", "Chromosome", "Position", "Strand", "Total.miRNA.reads", "RPM..reads.per.million.")
all <- read_all_files_in_dir_with_columns(temp_dir, required_columns)

# %%
all
# Out:
#       miRNA           Chromosome Position  Strand Total.miRNA.reads
# 1     hsa-miR-378c    chr10      132760851 -        7
# 2     hsa-mir-1321    chrX       85090785  +       26
# 3     hsa-miR-378d    chr8       94928250  -        2
# 4     hsa-miR-2110    chr10      115933864 -        5
# 5     hsa-mir-200b    chr1       1102484   +        2
# 6     hsa-miR-125a-5p chr19      52196507  +        7
# 7     hsa-mir-671     chr7       150935507 +        1
# 8     hsa-miR-193a-5p chr17      29887015  +        1
# 9     hsa-mir-378     chr5       149112388 +        4
# 10    hsa-mir-3202-1  chrX       153246548 +        2
# 11    hsa-mir-5096    chr4       79741906  +        9
# 12    hsa-mir-320a    chr8       22102475  -       37
# 13    hsa-miR-32      chr9       111808509 -        8
# 14    hsa-miR-30b     chr8       135812763 -        7
# 15    hsa-miR-30c     chr6       72086663  -        7
# 16    hsa-miR-30d     chr8       135817119 -       25
# 17    hsa-miR-30e     chr1       41220027  +       53
# 18    hsa-miR-30b*    chr8       135812763 -        2
# 19    hsa-miR-643     chr19      52785050  +        1
# 20    hsa-miR-1260    chr14      77732561  +        2
# 21    hsa-miR-17*     chr13      92002859  +       11
# 22    hsa-miR-150     chr19      50004042  -      391
# 23    hsa-mir-101-2   chr9       4850297   +       16
# 24    hsa-miR-331-5p  chr12      95702196  +        1
# 25    hsa-mir-101-1   chr1       65524117  -       13
# 26    hsa-mir-27b     chr9       97847727  +        8
# 27    hsa-mir-128-1   chr2       136422967 +        3
# 28    hsa-miR-128     chr3       35785968  +        9
# 29    hsa-miR-500a    chrX       49773039  +        2
# 30    hsa-mir-128-2   chr3       35785968  +        3
# ...   ...             ...        ...       ...    ...
# 36762 hsa-miR-21*     chr17      57918627  +        415
# 36763 hsa-miR-185*    chr22      20020662  +         14
# 36764 hsa-miR-331-3p  chr12      95702196  +          8
# 36765 hsa-miR-214     chr1       172107938 -          3
# 36766 hsa-miR-215     chr1       220291195 -          2
# 36767 hsa-miR-744     chr17      11985216  +        236
# 36768 hsa-mir-4781    chr1       54519752  +          3
# 36769 hsa-miR-210     chr11      568089    -         51
# 36770 hsa-miR-4510    chr15      36219057  +          1
# 36771 hsa-miR-4458    chr5       8461038   +          1
# 36772 hsa-miR-92b*    chr1       155164968 +          8
# 36773 hsa-miR-25*     chr7       99691183  -         16
# 36774 hsa-mir-3615    chr17      72744752  +         10
# 36775 hsa-miR-135b    chr1       205417430 -         34
# 36776 hsa-miR-589*    chr7       5535450   -          1
# 36777 hsa-mir-2355    chr2       207974711 -          7
# 36778 hsa-miR-26b     chr2       219267369 +      16260
# 36779 hsa-mir-1268b   chr17      78072627  +         13
# 36780 hsa-mir-199a-1  chr19      10928102  -          2
# 36781 hsa-mir-628     chr15      55665138  -          3
# 36782 hsa-mir-199a-2  chr1       172113675 -          2
# 36783 hsa-miR-146a    chr5       159912359 +       1470
# 36784 hsa-mir-378g    chr1       95211416  -          1
# 36785 hsa-miR-30e*    chr1       41220027  +       2153
# 36786 hsa-miR-374a*   chrX       73507121  -         10
# 36787 hsa-miR-1285    chr7       91833329  -         19
# 36788 hsa-miR-1287    chr10      100154975 -         18
# 36789 hsa-miR-100     chr11      122022937 -          2
# 36790 hsa-miR-101     chr9       4850297   +       1306
# 36791 hsa-miR-107     chr10      91352504  -       4501
#       RPM..reads.per.million. healthy cellType
# 1      1                      TRUE    Naive
# 2      6                      TRUE    Naive
# 3      1                      TRUE    Naive
# 4      1                      TRUE    Naive
# 5      1                      TRUE    Naive
# 6      1                      TRUE    Naive
# 7      1                      TRUE    Naive
# 8      1                      TRUE    Naive
# 9      1                      TRUE    Naive
# 10     1                      TRUE    Naive
# 11     2                      TRUE    Naive
# 12     8                      TRUE    Naive
# 13     1                      TRUE    Naive
# 14     1                      TRUE    Naive
# 15     1                      TRUE    Naive
# 16     5                      TRUE    Naive
# 17    12                      TRUE    Naive
# 18     1                      TRUE    Naive
# 19     1                      TRUE    Naive
# 20     1                      TRUE    Naive
# 21     2                      TRUE    Naive
# 22    91                      TRUE    Naive
# 23     3                      TRUE    Naive
# 24     1                      TRUE    Naive
# 25     3                      TRUE    Naive
# 26     1                      TRUE    Naive
# 27     1                      TRUE    Naive
# 28     2                      TRUE    Naive
# 29     1                      TRUE    Naive
# 30     1                      TRUE    Naive
# ...   ...                     ...     ...
# 36762   45                    FALSE   Ttm
# 36763    1                    FALSE   Ttm
# 36764    1                    FALSE   Ttm
# 36765    1                    FALSE   Ttm
# 36766    1                    FALSE   Ttm
# 36767   26                    FALSE   Ttm
# 36768    1                    FALSE   Ttm
# 36769    5                    FALSE   Ttm
# 36770    1                    FALSE   Ttm
# 36771    1                    FALSE   Ttm
# 36772    1                    FALSE   Ttm
# 36773    1                    FALSE   Ttm
# 36774    1                    FALSE   Ttm
# 36775    3                    FALSE   Ttm
# 36776    1                    FALSE   Ttm
# 36777    1                    FALSE   Ttm
# 36778 1795                    FALSE   Ttm
# 36779    1                    FALSE   Ttm
# 36780    1                    FALSE   Ttm
# 36781    1                    FALSE   Ttm
# 36782    1                    FALSE   Ttm
# 36783  162                    FALSE   Ttm
# 36784    1                    FALSE   Ttm
# 36785  237                    FALSE   Ttm
# 36786    1                    FALSE   Ttm
# 36787    2                    FALSE   Ttm
# 36788    1                    FALSE   Ttm
# 36789    1                    FALSE   Ttm
# 36790  144                    FALSE   Ttm
# 36791  497                    FALSE   Ttm

# %%
print(required_columns)
# Out:
# [[1]]
# [1] "miRNA"
#
# [[2]]
# [1] "Chromosome"
#
# [[3]]
# [1] "Position"
#
# [[4]]
# [1] "Strand"
#
# [[5]]
# [1] "Total.miRNA.reads"
#
# [[6]]
# [1] "RPM..reads.per.million."
